# %%
print("長庚大學\n醫學系\n楊育綸")
# Out:
# 長庚大學
# 醫學系
# 楊育綸

# %%
a=int(input())
print(a>10)
# Out:
# 10
# False

# %%
a=3
b=5
print(a**b)
# Out:
# 243

# %%
a=3
b=5
print(a!=b)
# Out:
# True

# %%
a=3
b=5
a/=b
print(a)
# Out:
# 0.6

# %%
a=3
b=5
c=a/b
print(c)
# Out:
# 0.6
